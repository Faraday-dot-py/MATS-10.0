# %% [markdown]
# # Gemma-2-2B-IT: Reference-State Matching Notebook
#
# This notebook:
#
# - Loads **gemma-2-2b-it**.
# - Uses a **reference prompt** (default `"Talk about cats."`).
# - Optimizes a continuous **soft prompt** so that its hidden states at some layer match those from the reference prompt.
# - Projects the soft prompt back to tokens to get a *different* discrete prompt.
# - Compares internal state similarity between the reference prompt, the continuous soft prompt, and the discrete alternative prompt.

# %%
import math
from typing import List, Tuple

import torch
from torch import nn
from transformers import AutoModelForCausalLM, AutoTokenizer, AutoConfig

# %%
def get_device() -> torch.device:
    return torch.device("cuda" if torch.cuda.is_available() else "cpu")

device = get_device()
print("Using device:", device)
# Out:
# Using device: cuda

# %%
def load_model_and_tokenizer(
    model_name: str = "google/gemma-2-2b-it",
) -> Tuple[AutoModelForCausalLM, AutoTokenizer]:
    """
    Load Gemma-2 2B IT and its tokenizer.
    You need to have accepted the license on Hugging Face.
    """
    print(f"Loading model '{model_name}'...")
    config = AutoConfig.from_pretrained(model_name)
    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        config=config,
        torch_dtype=torch.float32,   # keep life simple, avoid bfloat issues
    )
    tokenizer = AutoTokenizer.from_pretrained(model_name)

    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    model.eval()
    return model, tokenizer


model, tokenizer = load_model_and_tokenizer("google/gemma-2-2b-it")
model.to(device)
# Out:
# Loading model 'google/gemma-2-2b-it'...
# config.json:   0%|          | 0.00/838 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json:   0%|          | 0.00/24.2k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/241M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/47.0k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# Gemma2ForCausalLM(
#   (model): Gemma2Model(
#     (embed_tokens): Embedding(256000, 2304, padding_idx=0)
#     (layers): ModuleList(
#       (0-25): 26 x Gemma2DecoderLayer(
#         (self_attn): Gemma2Attention(
#           (q_proj): Linear(in_features=2304, out_features=2048, bias=False)
#           (k_proj): Linear(in_features=2304, out_features=1024, bias=False)
#           (v_proj): Linear(in_features=2304, out_features=1024, bias=False)
#           (o_proj): Linear(in_features=2048, out_features=2304, bias=False)
#         )
#         (mlp): Gemma2MLP(
#           (gate_proj): Linear(in_features=2304, out_features=9216, bias=False)
#           (up_proj): Linear(in_features=2304, out_features=9216, bias=False)
#           (down_proj): Linear(in_features=9216, out_features=2304, bias=False)
#           (act_fn): GELUTanh()
#         )
#         (input_layernorm): Gemma2RMSNorm((2304,), eps=1e-06)
#         (post_attention_layernorm): Gemma2RMSNorm((2304,), eps=1e-06)
#         (pre_feedforward_layernorm): Gemma2RMSNorm((2304,), eps=1e-06)
#         (post_feedforward_layernorm): Gemma2RMSNorm((2304,), eps=1e-06)
#       )
#     )
#     (norm): Gemma2RMSNorm((2304,), eps=1e-06)
#     (rotary_emb): Gemma2RotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=2304, out_features=256000, bias=False)
# )

# %%
# You can change this to anything you like
reference_prompt = "Talk about cats."

# Layer to match (0 = embeddings, 1..n_layers; -1 = final hidden states)
# For Gemma-2-2b-it, something like 20 or -1 is reasonable to start with.
layer_idx = 2

@torch.no_grad()
def get_hidden_states_for_prompt(
    prompt: str,
    model: AutoModelForCausalLM,
    tokenizer: AutoTokenizer,
    layer_idx: int,
    device: torch.device,
) -> torch.Tensor:
    """
    Return hidden states at the given layer for the entire prompt.
    Shape: [T, d_model]
    """
    enc = tokenizer(
        prompt,
        return_tensors="pt",
        padding=False,
        truncation=True,
    )
    input_ids = enc["input_ids"].to(device)  # [1, T]

    outputs = model(
        input_ids=input_ids,
        output_hidden_states=True,
    )
    hidden_states = outputs.hidden_states  # tuple length = n_layers+1
    hs_layer = hidden_states[layer_idx]    # [1, T, d_model]
    return hs_layer[0].detach()            # [T, d_model]


H_ref = get_hidden_states_for_prompt(
    reference_prompt,
    model,
    tokenizer,
    layer_idx=layer_idx,
    device=device,
)

T_ref, d_model = H_ref.shape
print(f"Reference prompt: {reference_prompt!r}")
print(f"Reference hidden states shape: {H_ref.shape} (T={T_ref}, d={d_model})")
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Reference prompt: 'Talk about cats.'
# Reference hidden states shape: torch.Size([5, 2304]) (T=5, d=2304)

# %%
banned_words = [
    "Talk",
    " Talk",
    "Talk ",

    "talk",
    " talk",
    "talk ",

    "TALK",
    " TALK",
    "TALK ",

    "about",
    " about",
    "about ",

    "About",
    " About",
    "About ",

    "ABOUT",
    " ABOUT",
    "ABOUT ",

    "Cats",
    " Cats",
    "Cats ",

    "cats",
    " cats",
    "cats ",

    "CATS",
    " CATS",
    "CATS ",

    "Talk.",
    " Talk.",
    "Talk .",

    "talk.",
    " talk.",
    "talk .",

    "TALK.",
    " TALK.",
    "TALK .",

    "about.",
    " about.",
    "about .",

    "About.",
    " About.",
    "About .",

    "ABOUT.",
    " ABOUT.",
    "ABOUT .",

    "Cats.",
    " Cats.",
    "Cats .",

    "cats.",
    " cats.",
    "cats .",

    "CATS.",
    " CATS.",
    "CATS .",
]


# banned_words = "Talk about cats."

banned_weight = 1.5

# %%
class SoftPromptMatcher(nn.Module):
    """
    Learn a soft prompt whose hidden states at a given layer
    match those of a reference prompt as closely as possible,
    while discouraging similarity to some banned words.
    """

    def __init__(
        self,
        model: AutoModelForCausalLM,
        tokenizer: AutoTokenizer,
        d_model: int,
        prompt_length: int,
        layer_idx: int,
        H_ref: torch.Tensor,
        device: torch.device,
        banned_words=None,
        banned_weight: float = 0.0,
    ):
        super().__init__()
        self.model = model
        self.tokenizer = tokenizer
        self.layer_idx = layer_idx
        self.device = device

        # Reference states: [T_ref, d_model]
        self.register_buffer("H_ref", H_ref.to(device))

        self.prompt_length = prompt_length
        self.banned_weight = banned_weight

        # Initialize soft prompt with small random noise
        self.soft_prompt = nn.Parameter(
            torch.randn(prompt_length, d_model, device=device) * 0.02
        )

        # Precompute phrase-level embeddings for banned words (if any)
        token_embed = self.model.get_input_embeddings()
        phrase_vecs = []
        if banned_words:
            for w in banned_words:
                ids = tokenizer(w, add_special_tokens=False).input_ids
                if not ids:
                    continue
                # average subtoken embeddings for this word/phrase
                emb = token_embed.weight[ids].detach().to(device).mean(dim=0)
                phrase_vecs.append(emb)

        if phrase_vecs:
            banned_emb = torch.stack(phrase_vecs, dim=0)   # [n_banned, d]
            banned_emb = banned_emb / (
                banned_emb.norm(dim=-1, keepdim=True) + 1e-8
            )
            self.register_buffer("banned_emb", banned_emb)
        else:
            self.banned_emb = None

    def forward(self) -> Tuple[torch.Tensor, torch.Tensor]:
        """
        Run the model with the soft prompt and compute:
        - H_soft : [T, d] hidden states at the target layer
        - loss   : MSE between normalized H_soft and H_ref (tokenwise)
                   + banned-word penalty
        """
        # [1, T, d_model]
        inputs_embeds = self.soft_prompt.unsqueeze(0)

        outputs = self.model(
            inputs_embeds=inputs_embeds,
            output_hidden_states=True,
        )
        hidden_states = outputs.hidden_states
        hs_layer = hidden_states[self.layer_idx]  # [1, T, d_model]
        H_soft = hs_layer[0]                      # [T, d_model]

        # If lengths differ for some reason, crop to min length
        T_soft = H_soft.shape[0]
        T_ref = self.H_ref.shape[0]
        T = min(T_soft, T_ref)

        H_soft_sel = H_soft[:T]       # [T, d]
        H_ref_sel = self.H_ref[:T]    # [T, d]

        # Normalize each token vector before comparing (cosine-ish)
        H_soft_norm = H_soft_sel / (H_soft_sel.norm(dim=-1, keepdim=True) + 1e-8)
        H_ref_norm = H_ref_sel / (H_ref_sel.norm(dim=-1, keepdim=True) + 1e-8)

        # Base loss: MSE between normalized states
        mse_loss = ((H_soft_norm - H_ref_norm) ** 2).mean()

        # Banned-word penalty: avoid average hidden state aligning with banned embeddings
        penalty = 0.0
        if self.banned_emb is not None and self.banned_weight > 0.0:
            # average over tokens
            h_mean = H_soft_norm.mean(dim=0)                 # [d]
            sim_to_banned = torch.matmul(self.banned_emb, h_mean)  # [n_banned]
            # penalize large |similarity|^2
            penalty = self.banned_weight * (sim_to_banned.pow(2).mean())

        loss = mse_loss + penalty

        return H_soft, loss

# %%
T_ref
# Out:
# 5

# %%
prompt_length = T_ref  # try same length as reference prompt
matcher = SoftPromptMatcher(
    model=model,
    tokenizer=tokenizer,
    d_model=d_model,
    prompt_length=prompt_length,
    layer_idx=layer_idx,
    H_ref=H_ref,
    device=device,
    banned_words=banned_words,
    banned_weight=banned_weight,
).to(device)

steps = 1
lr = 1e-2

optimizer = torch.optim.Adam([matcher.soft_prompt], lr=lr)

history = []

for step in range(steps):
    optimizer.zero_grad()
    _, loss = matcher()
    loss.backward()
    optimizer.step()

    history.append(loss.item())

    if step % max(1, steps // 10) == 0 or step == steps - 1:
        print(f"[step {step:4d}] loss={loss.item():.6f}")
# Out:
# [step    0] loss=0.001644

# %%
@torch.no_grad()
def project_soft_prompt_to_tokens(
    soft_prompt: torch.Tensor,
    model: AutoModelForCausalLM,
    tokenizer: AutoTokenizer,
    top_k: int = 1,
) -> List[int]:
    """
    For each soft embedding vector, pick the nearest token embedding(s) by cosine similarity.

    soft_prompt: [T, d]
    Returns: list of T token IDs.
    """
    token_embed = model.get_input_embeddings().weight  # [V, d]
    device = token_embed.device

    soft_prompt = soft_prompt.to(device)

    V, d = token_embed.shape
    T = soft_prompt.shape[0]

    # Normalize
    token_embed_norm = token_embed / (token_embed.norm(dim=-1, keepdim=True) + 1e-8)
    soft_norm = soft_prompt / (soft_prompt.norm(dim=-1, keepdim=True) + 1e-8)

    token_ids = []

    for i in range(T):
        e = soft_norm[i]  # [d]
        sims = torch.matmul(token_embed_norm, e)  # [V]
        if top_k == 1:
            best_id = torch.argmax(sims).item()
            token_ids.append(best_id)
        else:
            topk = torch.topk(sims, k=top_k)
            best_id = topk.indices[0].item()
            token_ids.append(best_id)

    return token_ids


soft_prompt_learned = matcher.soft_prompt.detach().cpu()
alt_token_ids = project_soft_prompt_to_tokens(
    soft_prompt_learned, model, tokenizer, top_k=1
)
alt_prompt_str = tokenizer.decode(alt_token_ids, skip_special_tokens=True)

print("Reference prompt:", repr(reference_prompt))
print("Alternative prompt:", repr(alt_prompt_str))
print("Are they exactly equal?", reference_prompt == alt_prompt_str)
# Out:
# Reference prompt: 'Talk about cats.'
# Alternative prompt: 'Wyë賓cur MOMENT'
# Are they exactly equal? False

# %%
@torch.no_grad()
def hidden_sequence_for_prompt(
    prompt: str,
    model: AutoModelForCausalLM,
    tokenizer: AutoTokenizer,
    layer_idx: int,
    device: torch.device,
) -> torch.Tensor:
    """
    Get hidden states [T, d] at layer_idx for a text prompt.
    """
    enc = tokenizer(
        prompt,
        return_tensors="pt",
        padding=False,
        truncation=True,
    )
    input_ids = enc["input_ids"].to(device)
    outputs = model(
        input_ids=input_ids,
        output_hidden_states=True,
    )
    hs_layer = outputs.hidden_states[layer_idx][0]  # [T, d]
    return hs_layer.detach()


def sequence_cosine_similarity(
    H_a: torch.Tensor,
    H_b: torch.Tensor,
) -> float:
    """
    Average cosine similarity over token positions, after aligning lengths.
    """
    T = min(H_a.shape[0], H_b.shape[0])
    A = H_a[:T]
    B = H_b[:T]

    A_norm = A / (A.norm(dim=-1, keepdim=True) + 1e-8)
    B_norm = B / (B.norm(dim=-1, keepdim=True) + 1e-8)

    cos_t = (A_norm * B_norm).sum(dim=-1)  # [T]
    return cos_t.mean().item()


# 1) Reference hidden states (already have H_ref)
H_ref_eval = H_ref.to(device)

# 2) Continuous soft prompt hidden states
with torch.no_grad():
    H_soft_continuous, _ = matcher()     # [T_soft, d]
    H_soft_continuous = H_soft_continuous.detach()

# 3) Discrete alternative prompt hidden states
H_alt_discrete = hidden_sequence_for_prompt(
    alt_prompt_str,
    model,
    tokenizer,
    layer_idx=layer_idx,
    device=device,
)

sim_ref_soft = sequence_cosine_similarity(H_ref_eval, H_soft_continuous)
sim_ref_alt = sequence_cosine_similarity(H_ref_eval, H_alt_discrete)

print("Average cosine similarity with reference states:")
print(f"  Continuous soft prompt: {sim_ref_soft:.4f}")
print(f"  Discrete alternative prompt: {sim_ref_alt:.4f}")
# Out:
# Average cosine similarity with reference states:
#   Continuous soft prompt: -0.0043
#   Discrete alternative prompt: 0.4030

# %%
random_prompt = "This is a totally random unrelated sentence about weather."

H_random = hidden_sequence_for_prompt(
    random_prompt,
    model,
    tokenizer,
    layer_idx=layer_idx,
    device=device,
)

sim_ref_random = sequence_cosine_similarity(H_ref_eval, H_random)

print("Random baseline prompt:", repr(random_prompt))
print(f"  Similarity(ref, random)   = {sim_ref_random:.4f}")
print(f"  Similarity(ref, alt)      = {sim_ref_alt:.4f}")
print(f"  Similarity(ref, soft)     = {sim_ref_soft:.4f}")
# Out:
# Random baseline prompt: 'This is a totally random unrelated sentence about weather.'
#   Similarity(ref, random)   = 0.4687
#   Similarity(ref, alt)      = 0.4030
#   Similarity(ref, soft)     = -0.0043

# %%
# If you already defined generate_from_prompt earlier, you can delete this block.
@torch.no_grad()
def generate_from_prompt_local(
    prompt: str,
    model: AutoModelForCausalLM,
    tokenizer: AutoTokenizer,
    device: torch.device,
    max_new_tokens: int = 80,
    temperature: float = 0.8,
    repetition_penalty: float = 1.1,
    no_repeat_ngram_size: int = 3,
) -> str:
    enc = tokenizer(prompt, return_tensors="pt").to(device)
    out_ids = model.generate(
        **enc,
        max_new_tokens=max_new_tokens,
        do_sample=True,
        temperature=temperature,
        pad_token_id=tokenizer.eos_token_id,
        repetition_penalty=repetition_penalty,
        no_repeat_ngram_size=no_repeat_ngram_size,
    )
    return tokenizer.decode(out_ids[0], skip_special_tokens=True)

# def project_state_to_tokens():
#     with torch.no_grad():
#         soft_prompt_learned = matcher.soft_prompt.detach().cpu()
#         alt_token_ids = project_soft_prompt_to_tokens(
#             soft_prompt_learned,
#             model,
#             tokenizer,
#             top_k=1,
#         )
#         alt_prompt_str = tokenizer.decode(alt_token_ids, skip_special_tokens=True)

#     return alt_prompt_str

# print("=== Reference prompt ===")
# print("Prompt:", repr(reference_prompt))
# ref_gen = generate_from_prompt_local(
#     reference_prompt,
#     model,
#     tokenizer,
#     device=device,
# )
# print("Generation:\n", ref_gen)

# print("\n=== Alternative (matched) prompt ===")
# print("Prompt:", repr(alt_prompt_str))
# alt_gen = generate_from_prompt_local(
#     alt_prompt_str,
#     model,
#     tokenizer,
#     device=device,
# )
# print("Generation:\n", alt_gen)
# print(alt_gen == ref_gen)

# %%
# === Layer sweep with fixed seeds, early stopping, and generation ===

import random
import numpy as np
import torch

target_layers = range(0, 26, 2)

steps = 1000
lr = 1e-2

n_tokens_to_generate = 80      # how many *new* tokens to generate
lower_loss_threshold = 1e-4    # early stopping threshold

layer_prompts = {}
layer_histories = {}

# Global base seed – controls everything
base_seed = 4738

for layer_idx in target_layers:
    # ----- set seeds so this run is fully reproducible -----
    # If you want the *same* seed for every layer, just use base_seed
    # instead of base_seed + layer_idx.
    layer_seed = base_seed + layer_idx

    random.seed(layer_seed)
    np.random.seed(layer_seed)
    torch.manual_seed(layer_seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(layer_seed)

    print("\n" + "=" * 30)
    print(f" Optimizing soft prompt for layer {layer_idx} (seed={layer_seed})")
    print("=" * 30)

    # 1) Reference hidden states for this layer
    H_ref_layer = get_hidden_states_for_prompt(
        reference_prompt,
        model,
        tokenizer,
        layer_idx=layer_idx,
        device=device,
    )
    T_ref, d_model = H_ref_layer.shape
    print(f"Layer {layer_idx}: H_ref shape = {H_ref_layer.shape} (T={T_ref}, d={d_model})")

    # 2) Build matcher for this layer
    matcher = SoftPromptMatcher(
        model=model,
        tokenizer=tokenizer,
        d_model=d_model,
        prompt_length=prompt_length,
        layer_idx=layer_idx,
        H_ref=H_ref_layer,
        device=device,
        banned_words=banned_words,
        banned_weight=banned_weight,
    ).to(device)

    optimizer = torch.optim.Adam([matcher.soft_prompt], lr=lr)
    history = []

    # 3) Optimize with early stopping
    for step in range(steps):
        optimizer.zero_grad()
        _, loss = matcher()
        loss.backward()
        optimizer.step()

        loss_value = loss.item()
        history.append(loss_value)

        if step % max(1, steps // 20) == 0 or step == steps - 1:
            optimizer.zero_grad()
            print(f"[layer {layer_idx:2d} | step {step:4d}] loss={loss_value:.6f}")

        if loss_value < lower_loss_threshold:
            print(
                f"--Early stopping on step {step}--\n"
                f"Loss of {loss_value:.6f} < {lower_loss_threshold}"
            )
            break

        # elif current_prompt == "Talk about cats.":
        #     print(
        #         f"--Early stopping on step {step}--\n"
        #         f"Model reached original prompt with loss {loss_value:.6f}"
        #     )
        #     reached_original_prompt = True
        #     break



    layer_histories[layer_idx] = history

    # 4) Project learned soft prompt to discrete tokens and decode
    with torch.no_grad():
        soft_prompt_learned = matcher.soft_prompt.detach().cpu()
        alt_token_ids = project_soft_prompt_to_tokens(
            soft_prompt_learned,
            model,
            tokenizer,
            top_k=1,
        )
        alt_prompt_str = tokenizer.decode(alt_token_ids)

    layer_prompts[layer_idx] = alt_prompt_str

    if alt_prompt_str == reference_prompt:
        print(f"Model reached original prompt with loss {loss_value:.6f}")

    print(f"\nLayer {layer_idx} alternative prompt:")
    print(repr(alt_prompt_str))

    # 5) Generate n tokens after this alternative starter prompt
    # Re-seed before generation to keep sampling reproducible as well
    random.seed(layer_seed)
    np.random.seed(layer_seed)
    torch.manual_seed(layer_seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(layer_seed)

    alt_gen = generate_from_prompt_local(
        alt_prompt_str,
        model,
        tokenizer,
        device=device,
        max_new_tokens=n_tokens_to_generate,
    )
    print(f"\nSample generation from layer {layer_idx} prompt "
          f"(first {n_tokens_to_generate} new tokens):")
    print(alt_gen)
# Out:
# ==============================
#  Optimizing soft prompt for layer 0 (seed=4738)
# ==============================
# Layer 0: H_ref shape = torch.Size([5, 2304]) (T=5, d=2304)
# [layer  0 | step    0] loss=0.000971
# [layer  0 | step   50] loss=0.000815
# [layer  0 | step  100] loss=0.000759
# [layer  0 | step  150] loss=0.000694
# [layer  0 | step  200] loss=0.000619
# [layer  0 | step  250] loss=0.000539
# [layer  0 | step  300] loss=0.000459
# [layer  0 | step  350] loss=0.000383
# [layer  0 | step  400] loss=0.000317
# [layer  0 | step  450] loss=0.000263
# [layer  0 | step  500] loss=0.000219
# [layer  0 | step  550] loss=0.000186
# [layer  0 | step  600] loss=0.000160
# [layer  0 | step  650] loss=0.000140
# [layer  0 | step  700] loss=0.000125
# [layer  0 | step  750] loss=0.000113
# [layer  0 | step  800] loss=0.000105
# --Early stopping on step 835--
# Loss of 0.000100 < 0.0001
#
# Layer 0 alternative prompt:
# '<bos>Talk about cats.'
#
# Sample generation from layer 0 prompt (first 80 new tokens):
# Talk about cats.
#
# Cats are amazing creatures! 😻  They're not just cuddly companions, but independent geniuses with unique personalities and captivating behavior. They rule our homes (in their own special way!). It's impossible to resist their mesmerizing eyes, playful antics, and soft fur. Here's a little bit of what makes them so wonderful:
#
# **Their Mysterious World:**
# * **The Art of
#
# ==============================
#  Optimizing soft prompt for layer 2 (seed=4740)
# ==============================
# Layer 2: H_ref shape = torch.Size([5, 2304]) (T=5, d=2304)
# [layer  2 | step    0] loss=0.001674
# [layer  2 | step   50] loss=0.000852
# [layer  2 | step  100] loss=0.000765
# [layer  2 | step  150] loss=0.000678
# [layer  2 | step  200] loss=0.000590
# [layer  2 | step  250] loss=0.000504
# [layer  2 | step  300] loss=0.000429
# [layer  2 | step  350] loss=0.000376
# [layer  2 | step  400] loss=0.000333
# [layer  2 | step  450] loss=0.000297
# [layer  2 | step  500] loss=0.000264
# [layer  2 | step  550] loss=0.000236
# [layer  2 | step  600] loss=0.000211
# [layer  2 | step  650] loss=0.000189
# [layer  2 | step  700] loss=0.000171
# [layer  2 | step  750] loss=0.000155
# [layer  2 | step  800] loss=0.000141
# [layer  2 | step  850] loss=0.000130
# [layer  2 | step  900] loss=0.000121
# [layer  2 | step  950] loss=0.000113
# [layer  2 | step  999] loss=0.000106
#
# Layer 2 alternative prompt:
# '<bos>Talk about cats<bos>'
#
# Sample generation from layer 2 prompt (first 80 new tokens):
# Talk about catsI need to create a blog post about your favorite things about living in a small city.
#
# **Here's the unique angle:**
#
# Instead of focusing on how cute and cuddly cats are, I want to find a different perspective:
#
# The overlooked benefits of being cat owner and enjoying life in a smaller urban environment.
#
# **Possible title ideas:**
#
# * Unfurling the Charm of
#
# ==============================
#  Optimizing soft prompt for layer 4 (seed=4742)
# ==============================
# Layer 4: H_ref shape = torch.Size([5, 2304]) (T=5, d=2304)
# [layer  4 | step    0] loss=0.001632
# [layer  4 | step   50] loss=0.000654
# [layer  4 | step  100] loss=0.000539
# [layer  4 | step  150] loss=0.000442
# [layer  4 | step  200] loss=0.000358
# [layer  4 | step  250] loss=0.000286
# [layer  4 | step  300] loss=0.000231
# [layer  4 | step  350] loss=0.000192
# [layer  4 | step  400] loss=0.000163
# [layer  4 | step  450] loss=0.000140
# [layer  4 | step  500] loss=0.000123
# [layer  4 | step  550] loss=0.000110
# --Early stopping on step 599--
# Loss of 0.000100 < 0.0001
#
# Layer 4 alternative prompt:
# ' timescale Talk ABOUT cats*.'
#
# Sample generation from layer 4 prompt (first 80 new tokens):
#  timescale Talk ABOUT cats*.
#
# ##  Cats: A Deeper Look 🐈‍⬛
#
# Let's talk about amazing, enigmatic creatures that are both pets and nature's wonders: **cats!**
#
# Here's a breakdown of some key things to know about these fascinating felines:
#
# **The Basics:**
# * **Domestication:** Cats have been domesticated for thousands of years, originating from wild cats in
#
# ==============================
#  Optimizing soft prompt for layer 6 (seed=4744)
# ==============================
# Layer 6: H_ref shape = torch.Size([5, 2304]) (T=5, d=2304)
# [layer  6 | step    0] loss=0.001225
# [layer  6 | step   50] loss=0.000611
# [layer  6 | step  100] loss=0.000448
# [layer  6 | step  150] loss=0.000335
# [layer  6 | step  200] loss=0.000248
# [layer  6 | step  250] loss=0.000189
# [layer  6 | step  300] loss=0.000150
# [layer  6 | step  350] loss=0.000124
# [layer  6 | step  400] loss=0.000106
# --Early stopping on step 425--
# Loss of 0.000100 < 0.0001
#
# Layer 6 alternative prompt:
# '<bos> Talk ABOUT Cats .'
#
# Sample generation from layer 6 prompt (first 80 new tokens):
#  Talk ABOUT Cats .
#
# Let's talk about cats! What are some fun facts you know about these fascinating creatures?
#
#
# For example:
# * **They can purr, and it’s not just for happiness.** Purring helps with healing and promoting circulation.
# *  **Cats have the ability to see in low-light conditions.** Their eyes have incredible vision in dim light, thanks in part
#
# ==============================
#  Optimizing soft prompt for layer 8 (seed=4746)
# ==============================
# Layer 8: H_ref shape = torch.Size([5, 2304]) (T=5, d=2304)
# [layer  8 | step    0] loss=0.001889
# [layer  8 | step   50] loss=0.000655
# [layer  8 | step  100] loss=0.000509
# [layer  8 | step  150] loss=0.000388
# [layer  8 | step  200] loss=0.000271
# [layer  8 | step  250] loss=0.000179
# [layer  8 | step  300] loss=0.000117
# --Early stopping on step 327--
# Loss of 0.000100 < 0.0001
#
# Layer 8 alternative prompt:
# '<bos> News ats Cats .'
#
# Sample generation from layer 8 prompt (first 80 new tokens):
#  News ats Cats .
#
# **Cats are independent creatures known for their grace, elegance, and aloofness.**
# - **Physical characteristics:** They have a distinctive sleek appearance with soft fur, sharp claws, and pointed ears.
# -  **Social Behaviors:** Cats are solitary by nature and spend most of their time alone unless they're in heat or with their kittens.
# -   **Physiological Reactions:**
#
# ==============================
#  Optimizing soft prompt for layer 10 (seed=4748)
# ==============================
# Layer 10: H_ref shape = torch.Size([5, 2304]) (T=5, d=2304)
# [layer 10 | step    0] loss=0.001303
# [layer 10 | step   50] loss=0.000454
# [layer 10 | step  100] loss=0.000316
# [layer 10 | step  150] loss=0.000210
# [layer 10 | step  200] loss=0.000132
# --Early stopping on step 246--
# Loss of 0.000100 < 0.0001
#
# Layer 10 alternative prompt:
# '<bos>andy tentang cats>.'
#
# Sample generation from layer 10 prompt (first 80 new tokens):
# andy tentang cats>.
#
# ##  Benefits of Cat Ownership
# Cats are beloved pets for a reason. They bring joy, companionship, and a whole lot of purrs to our lives. But what exactly are the benefits of having a feline friend? Here's a breakdown:
#
# **Emotional Benefits:**
#
# * **Stress Relief:** Petting a cat can lower blood pressure and reduce cortisol levels, promoting relaxation and reducing
#
# ==============================
#  Optimizing soft prompt for layer 12 (seed=4750)
# ==============================
# Layer 12: H_ref shape = torch.Size([5, 2304]) (T=5, d=2304)
# [layer 12 | step    0] loss=0.001298
# [layer 12 | step   50] loss=0.000459
# [layer 12 | step  100] loss=0.000344
# [layer 12 | step  150] loss=0.000267
# [layer 12 | step  200] loss=0.000210
# [layer 12 | step  250] loss=0.000173
# [layer 12 | step  300] loss=0.000149
# [layer 12 | step  350] loss=0.000137
# [layer 12 | step  400] loss=0.000100
# --Early stopping on step 401--
# Loss of 0.000100 < 0.0001
#
# Layer 12 alternative prompt:
# '첨高い aboutcatsFj'
#
# Sample generation from layer 12 prompt (first 80 new tokens):
# 첨高い aboutcatsFj3zZtU0
#
#
# ==============================
#  Optimizing soft prompt for layer 14 (seed=4752)
# ==============================
# Layer 14: H_ref shape = torch.Size([5, 2304]) (T=5, d=2304)
# [layer 14 | step    0] loss=0.001354
# [layer 14 | step   50] loss=0.000458
# [layer 14 | step  100] loss=0.000351
# [layer 14 | step  150] loss=0.000278
# [layer 14 | step  200] loss=0.000217
# [layer 14 | step  250] loss=0.000177
# [layer 14 | step  300] loss=0.000151
# [layer 14 | step  350] loss=0.000138
# [layer 14 | step  400] loss=0.000121
# [layer 14 | step  450] loss=0.000110
# [layer 14 | step  500] loss=0.000102
# --Early stopping on step 508--
# Loss of 0.000100 < 0.0001
#
# Layer 14 alternative prompt:
# ' conjuntos K «CAT Daniel'
#
# Sample generation from layer 14 prompt (first 80 new tokens):
#  conjuntos K «CAT Daniel».
#
# ##  Data Processing for the CAT Daniel Case Study
#
# This case study focuses on processing data associated with "CAT Daniel," a hypothetical system used in the context of a large-scale computer vision project.
#
# **1. Data Acquisition**
#    * **Source:** Images, videos, or other relevant datasets that contribute to the training and evaluation of the CAT model.
#
# **
#
# ==============================
#  Optimizing soft prompt for layer 16 (seed=4754)
# ==============================
# Layer 16: H_ref shape = torch.Size([5, 2304]) (T=5, d=2304)
# [layer 16 | step    0] loss=0.002162
# [layer 16 | step   50] loss=0.000529
# [layer 16 | step  100] loss=0.000376
# [layer 16 | step  150] loss=0.000296
# [layer 16 | step  200] loss=0.000240
# [layer 16 | step  250] loss=0.000212
# [layer 16 | step  300] loss=0.000174
# [layer 16 | step  350] loss=0.000152
# [layer 16 | step  400] loss=0.000151
# [layer 16 | step  450] loss=0.000121
# [layer 16 | step  500] loss=0.000115
# [layer 16 | step  550] loss=0.000103
# [layer 16 | step  600] loss=0.000197
# [layer 16 | step  650] loss=0.000144
# [layer 16 | step  700] loss=0.000123
# [layer 16 | step  750] loss=0.000111
# [layer 16 | step  800] loss=0.000102
# --Early stopping on step 815--
# Loss of 0.000100 < 0.0001
#
# Layer 16 alternative prompt:
# '曾<bos>programme cats várias'
#
# Sample generation from layer 16 prompt (first 80 new tokens):
# 曾programme cats várias vezes.
#
# ```python
# import random
#
# def generate_random_password(length):
#   """Generates a password with the specified length."""
#
#   characters = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789"
#   password = ''.join(random.choices(characters, k=length))
#   return password
#
# # Example usage
# password
#
# ==============================
#  Optimizing soft prompt for layer 18 (seed=4756)
# ==============================
# Layer 18: H_ref shape = torch.Size([5, 2304]) (T=5, d=2304)
# [layer 18 | step    0] loss=0.001264
# [layer 18 | step   50] loss=0.000483
# [layer 18 | step  100] loss=0.000348
# [layer 18 | step  150] loss=0.000264
# [layer 18 | step  200] loss=0.000192
# [layer 18 | step  250] loss=0.000131
# --Early stopping on step 282--
# Loss of 0.000100 < 0.0001
#
# Layer 18 alternative prompt:
# " politically__' свое アンドчо"
#
# Sample generation from layer 18 prompt (first 80 new tokens):
#  politically__' свое アンドчо
#
# ##   **"The Power of the Past: How Memories shape Our Present and Future"**
#
#
# This is a working title, but it embodies the core idea of this essay. It's intriguing because it touches on several important themes:
#
# * **Power:** The past has power over us both literally and metaphorically, guiding our current actions.
# * **Memories:** They are
#
# ==============================
#  Optimizing soft prompt for layer 20 (seed=4758)
# ==============================
# Layer 20: H_ref shape = torch.Size([5, 2304]) (T=5, d=2304)
# [layer 20 | step    0] loss=0.003540
# [layer 20 | step   50] loss=0.000513
# [layer 20 | step  100] loss=0.000372
# [layer 20 | step  150] loss=0.000300
# [layer 20 | step  200] loss=0.000253
# [layer 20 | step  250] loss=0.000223
# [layer 20 | step  300] loss=0.000190
# [layer 20 | step  350] loss=0.000167
# [layer 20 | step  400] loss=0.000153
# [layer 20 | step  450] loss=0.000135
# [layer 20 | step  500] loss=0.000128
# [layer 20 | step  550] loss=0.000373
# [layer 20 | step  600] loss=0.000224
# [layer 20 | step  650] loss=0.000184
# [layer 20 | step  700] loss=0.000160
# [layer 20 | step  750] loss=0.000144
# [layer 20 | step  800] loss=0.000131
# [layer 20 | step  850] loss=0.000121
# [layer 20 | step  900] loss=0.000113
# [layer 20 | step  950] loss=0.000106
# [layer 20 | step  999] loss=0.000101
#
# Layer 20 alternative prompt:
# " TAM उदाहरण ''). Cat✤"
#
# Sample generation from layer 20 prompt (first 80 new tokens):
#  TAM उदाहरण ''). Cat✤s
#     print('Cat'.join(cat_names))   # Join the list of cat names with a space
# ```
# **Explanation:**
#
# 1. **`cat_name` List:** This line creates a sample list of `cat_types`. Replace this with your actual list of data.
# 2. **Concatenating String Elements:** The core logic is in `'
#
# ==============================
#  Optimizing soft prompt for layer 22 (seed=4760)
# ==============================
# Layer 22: H_ref shape = torch.Size([5, 2304]) (T=5, d=2304)
# [layer 22 | step    0] loss=0.002634
# [layer 22 | step   50] loss=0.000508
# [layer 22 | step  100] loss=0.000390
# [layer 22 | step  150] loss=0.000312
# [layer 22 | step  200] loss=0.000260
# [layer 22 | step  250] loss=0.000218
# [layer 22 | step  300] loss=0.000195
# [layer 22 | step  350] loss=0.000184
# [layer 22 | step  400] loss=0.000171
# [layer 22 | step  450] loss=0.000161
# [layer 22 | step  500] loss=0.000150
# [layer 22 | step  550] loss=0.000150
# [layer 22 | step  600] loss=0.000135
# [layer 22 | step  650] loss=0.000140
# [layer 22 | step  700] loss=0.000132
# [layer 22 | step  750] loss=0.000349
# [layer 22 | step  800] loss=0.000216
# [layer 22 | step  850] loss=0.000180
# [layer 22 | step  900] loss=0.000161
# [layer 22 | step  950] loss=0.000148
# [layer 22 | step  999] loss=0.000137
#
# Layer 22 alternative prompt:
# 'рит賽بحث Catsliterally'
#
# Sample generation from layer 22 prompt (first 80 new tokens):
# рит賽بحث Catsliterally love to play! They're curious, playful little creatures who are always on the lookout for something new and exciting to try.
#
# **Here are some of the ways cats can keep themselves entertained:**
#
# * **Chasing toys:** Cats are natural hunters and enjoy chasing after things that move. This is a great way to release pent-up energy and satisfy their instinctual needs.
# * **
#
# ==============================
#  Optimizing soft prompt for layer 24 (seed=4762)
# ==============================
# Layer 24: H_ref shape = torch.Size([5, 2304]) (T=5, d=2304)
# [layer 24 | step    0] loss=0.006492
# [layer 24 | step   50] loss=0.000639
# [layer 24 | step  100] loss=0.000469
# [layer 24 | step  150] loss=0.000373
# [layer 24 | step  200] loss=0.000320
# [layer 24 | step  250] loss=0.000283
# [layer 24 | step  300] loss=0.000253
# [layer 24 | step  350] loss=0.000236
# [layer 24 | step  400] loss=0.000213
# [layer 24 | step  450] loss=0.000198
# [layer 24 | step  500] loss=0.000196
# [layer 24 | step  550] loss=0.000181
# [layer 24 | step  600] loss=0.000178
# [layer 24 | step  650] loss=0.000164
# [layer 24 | step  700] loss=0.000159
# [layer 24 | step  750] loss=0.000156
# [layer 24 | step  800] loss=0.000156
# [layer 24 | step  850] loss=0.000208
# [layer 24 | step  900] loss=0.000144
# [layer 24 | step  950] loss=0.000139
# [layer 24 | step  999] loss=0.000138
#
# Layer 24 alternative prompt:
# ' bütün désirالغctid廣'
#
# Sample generation from layer 24 prompt (first 80 new tokens):
#  bütün désirالغctid廣泛的。
#
# 在现代社会中，性欲是一种复杂且多元化的体验。它不仅仅是生理反应，而是情感、心理和社会因素的综合体。因此，我们应该避免将性欲简单地归纳为一个单一的概念或类别。
#
#
# **总结:**
#
# 性欲是一个多层次的体验，涉及生理、心理、社会、文化等因素
